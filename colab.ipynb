# %% [markdown]
# # Google Colab Notebook
#
# Run this notebook with Google Colab if you don't have an Nvidia GPU.
#
# Before running the cells, enable the GPU runtime: **Runtime → Change runtime type → Hardware accelerator → T4 GPU**.

# %%
import os

REPO = "https://github.com/themaxboucher/cuda_project.git"
DIR = "cuda_project"

if os.path.isdir(DIR):
    # !cd {DIR} && git pull # Pull latest changes
else:
    # !git clone {REPO} # Clone repo

# %%
# Complie and run
# !nvcc cuda_project/main.cu -o /tmp/out -lcublas && /tmp/out
